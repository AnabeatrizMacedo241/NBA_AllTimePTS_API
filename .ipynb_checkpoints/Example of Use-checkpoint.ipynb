# %% [markdown]
# ## Example of use -  NBA_AllTimePTS_API
# ### Ana Beatriz Macedo

# %%
from NBA_AllTimePTS_API import Stats
from selenium import webdriver

# %%
stats = Stats(webdriver.Chrome(),2)

# %%
stats.isLebronLeader()
# Out:
# Lebron is still the third all-time NBA points leader
# Lebron needs to score 2736 points in 101 games to surprass Kareem Abdul-Jabbar
# Lebron needs 1277 points in 47 games to surprass Karl Malone

# %%
stats.overallStats('Michael Jordan')
# Out:
# Michael Jordan stats:
# MPG:38.3
# PPG:30.1
# RPG:6.2
# APG:5.3
# SPG:2.3
# TOPG:2.7

# %%
stats.get_table()
# Out:
#                      Ranking      GP      MIN      PTS      FGM      FGA  \
# Player
# Kareem Abdul-Jabbar      1.0  1560.0  57446.0  38387.0  15837.0  28307.0
# Karl Malone              2.0  1476.0  54852.0  36928.0  13528.0  26210.0
# LeBron James             3.0  1321.0  50460.0  35651.0  13009.0  25823.0
# Kobe Bryant              4.0  1346.0  48643.0  33643.0  11719.0  26200.0
# Michael Jordan           5.0  1072.0  41010.0  32292.0  12192.0  24537.0
# ...                      ...     ...      ...      ...      ...      ...
# Chris Bosh              96.0   893.0  31936.0  17189.0   6209.0  12581.0
# Chris Webber            97.0   831.0  30852.0  17182.0   7192.0  15024.0
# Grant Hill              98.0  1026.0  34778.0  17137.0   6345.0  13126.0
# Rudy Gay                99.0  1015.0  32817.0  16965.0   6426.0  14143.0
# Bob Cousy              100.0   924.0  30165.0  16960.0   6168.0  16468.0
#
#                       FG%     3PM     3PA   3P%  ...   FT%    OREB     DREB  \
# ...

# %%
stats.mostAssists()
# Out:
# The player with mosts assists is John Stockton with 15806.0 assists at the 49.0th in the all-time points list

# %%
stats.best3P()
# Out:
# Best 3P% with, at least, 100 attempts is Stephen Curry with a 43.3% and he is at the 62.0th place on the all-time points list.

# %%
stats.bestOffensivePlayer()
# Out:
# Best offensive player efficiency is Wilt Chamberlain with a 41.5 and he is at the 7.0th place on the all-time points list.

# %%
stats.overallRebounds('Carmelo Anthony')
# Out:
# The overall reobunds of Carmelo Anthony:
# 25% offensive
# 75% defensive.
